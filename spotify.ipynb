# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("songs_normalize.csv")
df.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %%
df.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
df['duration_min'] = df['duration_ms'] / 60000
df.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre  \
# ...

# %%
df.drop(columns=['duration_ms'], inplace=True)
df.head()
# Out:
#            artist                    song  explicit  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again     False  2000          77
# 1       blink-182    All The Small Things     False  1999          79
# 2      Faith Hill                 Breathe     False  1999          66
# 3        Bon Jovi            It's My Life     False  2000          78
# 4          *NSYNC             Bye Bye Bye     False  2000          65
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.751   0.834    1    -5.444     0       0.0437        0.3000
# 1         0.434   0.897    0    -4.918     1       0.0488        0.0103
# 2         0.529   0.496    7    -9.007     1       0.0290        0.1730
# 3         0.551   0.913    0    -4.063     0       0.0466        0.0263
# 4         0.614   0.928    8    -4.806     0       0.0516        0.0408
#
#    instrumentalness  liveness  valence    tempo         genre  duration_min
# ...

# %%
df.columns
# Out:
# Index(['artist', 'song', 'explicit', 'year', 'popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'genre',
#        'duration_min'],
#       dtype='object')

# %%
columns = ['artist', 'song', 'explicit', 'year', 'popularity', 'danceability',
       'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'genre',
       'duration_min']
for col in columns:
    print(col)
    print(df[col].nunique())
    print(df[col].value_counts())
# Out:
# artist
# 835
# artist
# Rihanna           25
# Drake             23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
#                   ..
# Sidney Samson      1
# Cam’ron            1
# Elvis Presley      1
# Lucenzo            1
# Blanco Brown       1
# Name: count, Length: 835, dtype: int64
# song
# 1879
# song
# Sorry                   5
# Don't                   3
# Closer                  3
# Breathe                 3
# It's My Life            3
#                        ..
# Dani California         1
# What Hurts The Most     1
# You Know I'm No Good    1
# Ms. New Booty           1
# Circles                 1
# Name: count, Length: 1879, dtype: int64
# explicit
# 2
# explicit
# False    1449
# True      551
# Name: count, dtype: int64
# year
# 23
# year
# 2012    115
# 2017    111
# 2001    108
# 2018    107
# 2010    107
# 2014    104
# 2005    104
# 2011     99
# 2016     99
# 2015     99
# 2003     97
# 2008     97
# 2004     96
# 2006     95
# ...

# %%
# Step 1: Get the counts of each artist
artist_counts = df['artist'].value_counts()

# Step 2: Filter the DataFrame
filtered_df = df[df['artist'].isin(artist_counts[artist_counts > 3].index)]
filtered_df.artist.value_counts()
# Out:
# artist
# Rihanna                25
# Drake                  23
# Eminem                 21
# Calvin Harris          20
# Britney Spears         19
#                        ..
# Wiz Khalifa             4
# Jessie J                4
# Rita Ora                4
# Daniel Bedingfield      4
# Swedish House Mafia     4
# Name: count, Length: 136, dtype: int64

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df
# Out:
#       year  popularity  danceability  energy  key  loudness  mode  \
# 0     2000          77         0.751   0.834    1    -5.444     0
# 1     1999          79         0.434   0.897    0    -4.918     1
# 2     1999          66         0.529   0.496    7    -9.007     1
# 3     2000          78         0.551   0.913    0    -4.063     0
# 4     2000          65         0.614   0.928    8    -4.806     0
# ...    ...         ...           ...     ...  ...       ...   ...
# 1995  2019          79         0.842   0.734    1    -5.065     0
# 1996  2019          78         0.552   0.702    9    -5.707     1
# 1997  2019          69         0.847   0.678    9    -8.635     1
# 1998  2019          75         0.741   0.520    8    -7.513     1
# 1999  2019          85         0.695   0.762    0    -3.497     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0437        0.3000          0.000018    0.3550    0.894   95.053
# ...

# %%
corr = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Calculate the average for each boolean value
averages = df.groupby('explicit')['popularity'].mean()

# Create a bar plot
ax = averages.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Explicit or Not')
plt.ylabel('Average Popularity Score')
for i, value in enumerate(averages):
    ax.text(i, value, f'{value:.2f}', ha='center', va='bottom') 

plt.show()

# %%
average_genre = df.groupby('genre')['popularity'].mean()
average_genre = average_genre.sort_values(ascending=False)
# Create a bar plot
plt.figure(figsize=(12,12))
ax_g = average_genre.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Explicit or Not')
plt.ylabel('Average Popularity Score')

plt.show()

# %%
x = df.energy
y = df.loudness

plt.scatter(x, y)
plt.xlabel('energy level')
plt.ylabel('loudness')
plt.title('correlation between energy and loudness')
plt.show()

# %%
average_year = df.groupby('year')['popularity'].mean()
average_year = average_year.sort_values(ascending=False)
average_year.plot(kind='bar')
plt.show()
